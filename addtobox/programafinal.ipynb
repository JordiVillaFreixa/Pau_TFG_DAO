# %% [markdown]
# Després de ddiverses proves aconseguime el programa principal que ens ajudarà a crear un sistema de trehaloses transposades i disposades de manera aleatoria al sistema. Per escollir el número de trehaloses que volem al sistema hem d'anar a la linia de for in range() i canviar el número a que ens interessi. Allà on possa END, hauriem de posar TER.

# %%
import numpy as np
import os

def read_pdb(file_path):
    coordinates = []
    with open(file_path, 'r') as pdb_file:
        for line in pdb_file:
            if line.startswith('ATOM'):
                x = float(line[30:38])
                y = float(line[38:46])
                z = float(line[46:54])
                coordinates.append([x, y, z])
    return np.array(coordinates)

def write_pdb(file_path, coordinates,chain):
    with open(file_path, 'a') as pdb_file:
        with open('tre-copy.pdb', 'r') as template:
            for line, coord in zip(template, coordinates):
                x_str = f"{coord[0]:8.3f}"
                y_str = f"{coord[1]:8.3f}"
                z_str = f"{coord[2]:8.3f}"
                new_line = f"{line[:25]}{chain}{line[27:31]}{x_str}{y_str}{z_str}{line[54:]}"
                pdb_file.write(new_line)
        pdb_file.write('TER\n')
    pdb_file.close

def euler_rotation_matrix(phi, theta, psi):
    R_x = np.array([[1, 0, 0],
                    [0, np.cos(phi), -np.sin(phi)],
                    [0, np.sin(phi), np.cos(phi)]])
    
    R_y = np.array([[np.cos(theta), 0, np.sin(theta)],
                    [0, 1, 0],
                    [-np.sin(theta), 0, np.cos(theta)]])
    
    R_z = np.array([[np.cos(psi), -np.sin(psi), 0],
                    [np.sin(psi), np.cos(psi), 0],
                    [0, 0, 1]])
    
    R = np.dot(R_z, np.dot(R_y, R_x))
    
    return R

def apply_rotation_translation(file_path, phi, theta, psi, translation_vector):
    # Leer el archivo PDB y crear la matriz de coordenadas
    coordinates = read_pdb(file_path)
    print(phi,theta,psi)
    
    # Calcular la matriz de rotación
    R = euler_rotation_matrix(phi, theta, psi)
    
    # Aplicar la rotación a las coordenadas
    rotated_coordinates = np.dot(R, coordinates.T).T
    
    # Aplicar la translación a las coordenadas rotadas
    translated_coordinates = rotated_coordinates + translation_vector
    
    return translated_coordinates

# # Ángulos de Euler originales
# phi = np.pi / 4  # Ángulo de Euler phi (en radianes)
# theta = np.pi / 3  # Ángulo de Euler theta (en radianes)
# psi = np.pi / 6  # Ángulo de Euler psi (en radianes)

# # Vector de translación para cada molécula
# translation_vectors = [
#     np.array([10.0, 10.0, 10.0]),
#     np.array([20.0, 20.0, 20.0]),
#     np.array([30.0, 30.0, 30.0]),
#     np.array([40.0, 40.0, 40.0]),
#     np.array([50.0, 50.0, 50.0]),
#     np.array([60.0, 60.0, 60.0]),
#     np.array([70.0, 70.0, 70.0]),
#     np.array([80.0, 80.0, 80.0]),
#     np.array([90.0, 90.0, 90.0]),
#     np.array([100.0, 100.0, 100.0])
# ]

import os

# Specify the file path
# Crear 10 archivos PDB nuevos con coordenadas rotadas y transladadas
output_directory = "10tre"
file_path = "rotated_translated10.pdb"
output_file_path = os.path.join(output_directory, file_path)

# Check if the file exists before removing it
if os.path.exists(output_file_path):
    # Remove the file
    os.remove(output_file_path)
    print(f"File '{output_file_path}' has been successfully removed.")
else:
    print(f"File '{output_file_path}' does not exist.")




os.makedirs(output_directory, exist_ok=True)

for i in range(10):
    # Introducir variaciones aleatorias en los ángulos de Euler
    phi_random = np.random.uniform(0, 2*np.pi)  # Variación de +/- 15 grados
    theta_random = np.random.uniform(0,2*np.pi)
    psi_random = np.random.uniform(0,2*np.pi)
    translation_vector=[np.random.uniform(-20,20),np.random.uniform(-20,20),np.random.uniform(-20,20)]
    
    rotated_translated_coordinates = apply_rotation_translation('tre-copy.pdb', phi_random, theta_random, psi_random, translation_vector)
    chain=chr(ord('A') + i )
    write_pdb(output_file_path, rotated_translated_coordinates,chain)
    print(f"Archivo {output_file_path} cadena {chain} creado con éxito.")
# Out:
# File '10tre/rotated_translated10.pdb' has been successfully removed.
# 5.077310617770948 4.486432628624569 3.3937078334661073
# Archivo 10tre/rotated_translated10.pdb cadena A creado con éxito.
# 5.978447936167886 2.6388070740932394 4.946716711511867
# Archivo 10tre/rotated_translated10.pdb cadena B creado con éxito.
# 1.3191201645663662 2.7261985947417102 4.627936405786392
# Archivo 10tre/rotated_translated10.pdb cadena C creado con éxito.
# 2.5323909214274294 1.196538446625789 5.462190656216133
# Archivo 10tre/rotated_translated10.pdb cadena D creado con éxito.
# 4.767309224718672 0.8096190399130511 4.393575558312351
# Archivo 10tre/rotated_translated10.pdb cadena E creado con éxito.
# 5.206136053614887 6.096246199558673 0.6255906079533693
# Archivo 10tre/rotated_translated10.pdb cadena F creado con éxito.
# 3.9612294164993305 0.7055145206415845 5.468544304203683
# Archivo 10tre/rotated_translated10.pdb cadena G creado con éxito.
# 0.8325294843973686 5.42805260397496 5.537369598134091
# Archivo 10tre/rotated_translated10.pdb cadena H creado con éxito.
# 3.8832729818434975 4.985904288387519 2.832047549366648
# Archivo 10tre/rotated_translated10.pdb cadena I creado con éxito.
# 5.456746149721685 2.7206711670606154 2.2168440911582126
# Archivo 10tre/rotated_translated10.pdb cadena J creado con éxito.

# %% [markdown]
# Ara fem un nou fitxer amb 5

# %%
import numpy as np
import os

def read_pdb(file_path):
    coordinates = []
    with open(file_path, 'r') as pdb_file:
        for line in pdb_file:
            if line.startswith('ATOM'):
                x = float(line[30:38])
                y = float(line[38:46])
                z = float(line[46:54])
                coordinates.append([x, y, z])
    return np.array(coordinates)

def write_pdb(file_path, coordinates,chain):
    with open(file_path, 'a') as pdb_file:
        with open('tre-copy.pdb', 'r') as template:
            for line, coord in zip(template, coordinates):
                x_str = f"{coord[0]:8.3f}"
                y_str = f"{coord[1]:8.3f}"
                z_str = f"{coord[2]:8.3f}"
                new_line = f"{line[:25]}{chain}{line[27:31]}{x_str}{y_str}{z_str}{line[54:]}"
                pdb_file.write(new_line)
        pdb_file.write('END\n')
    pdb_file.close

def euler_rotation_matrix(phi, theta, psi):
    R_x = np.array([[1, 0, 0],
                    [0, np.cos(phi), -np.sin(phi)],
                    [0, np.sin(phi), np.cos(phi)]])
    
    R_y = np.array([[np.cos(theta), 0, np.sin(theta)],
                    [0, 1, 0],
                    [-np.sin(theta), 0, np.cos(theta)]])
    
    R_z = np.array([[np.cos(psi), -np.sin(psi), 0],
                    [np.sin(psi), np.cos(psi), 0],
                    [0, 0, 1]])
    
    R = np.dot(R_z, np.dot(R_y, R_x))
    
    return R

def apply_rotation_translation(file_path, phi, theta, psi, translation_vector):
    # Leer el archivo PDB y crear la matriz de coordenadas
    coordinates = read_pdb(file_path)
    print(phi,theta,psi)
    
    # Calcular la matriz de rotación
    R = euler_rotation_matrix(phi, theta, psi)
    
    # Aplicar la rotación a las coordenadas
    rotated_coordinates = np.dot(R, coordinates.T).T
    
    # Aplicar la translación a las coordenadas rotadas
    translated_coordinates = rotated_coordinates + translation_vector
    
    return translated_coordinates

# # Ángulos de Euler originales
# phi = np.pi / 4  # Ángulo de Euler phi (en radianes)
# theta = np.pi / 3  # Ángulo de Euler theta (en radianes)
# psi = np.pi / 6  # Ángulo de Euler psi (en radianes)

# # Vector de translación para cada molécula
# translation_vectors = [
#     np.array([10.0, 10.0, 10.0]),
#     np.array([20.0, 20.0, 20.0]),
#     np.array([30.0, 30.0, 30.0]),
#     np.array([40.0, 40.0, 40.0]),
#     np.array([50.0, 50.0, 50.0]),
#     np.array([60.0, 60.0, 60.0]),
#     np.array([70.0, 70.0, 70.0]),
#     np.array([80.0, 80.0, 80.0]),
#     np.array([90.0, 90.0, 90.0]),
#     np.array([100.0, 100.0, 100.0])
# ]

import os

# Specify the file path
# Crear 10 archivos PDB nuevos con coordenadas rotadas y transladadas
output_directory = "5tre"
file_path = "rotated_translated5.pdb"
output_file_path = os.path.join(output_directory, file_path)

# Check if the file exists before removing it
if os.path.exists(output_file_path):
    # Remove the file
    os.remove(output_file_path)
    print(f"File '{output_file_path}' has been successfully removed.")
else:
    print(f"File '{output_file_path}' does not exist.")




os.makedirs(output_directory, exist_ok=True)

for i in range(5):
    # Introducir variaciones aleatorias en los ángulos de Euler
    phi_random = np.random.uniform(0, 2*np.pi)  # Variación de +/- 15 grados
    theta_random = np.random.uniform(0,2*np.pi)
    psi_random = np.random.uniform(0,2*np.pi)
    translation_vector=[np.random.uniform(-20,20),np.random.uniform(-20,20),np.random.uniform(-20,20)]
    
    rotated_translated_coordinates = apply_rotation_translation('tre-copy.pdb', phi_random, theta_random, psi_random, translation_vector)
    chain=chr(ord('A') + i )
    write_pdb(output_file_path, rotated_translated_coordinates,chain)
    print(f"Archivo {output_file_path} cadena {chain} creado con éxito.")
# Out:
# File '5tre/rotated_translated5.pdb' has been successfully removed.
# 5.093648594854485 1.3058494086443944 0.5169512930920018
# Archivo 5tre/rotated_translated5.pdb cadena A creado con éxito.
# 2.6165668642094912 2.238760907665749 2.622738525519668
# Archivo 5tre/rotated_translated5.pdb cadena B creado con éxito.
# 2.556538853758188 1.092980195741926 6.1947549823029355
# Archivo 5tre/rotated_translated5.pdb cadena C creado con éxito.
# 0.6391768303400079 4.389617625384863 3.5814235440155175
# Archivo 5tre/rotated_translated5.pdb cadena D creado con éxito.
# 0.38398687345477367 5.288147380093678 3.397616939080618
# Archivo 5tre/rotated_translated5.pdb cadena E creado con éxito.

# %% [markdown]
# Ara amb 2

# %%
import numpy as np
import os

def read_pdb(file_path):
    coordinates = []
    with open(file_path, 'r') as pdb_file:
        for line in pdb_file:
            if line.startswith('ATOM'):
                x = float(line[30:38])
                y = float(line[38:46])
                z = float(line[46:54])
                coordinates.append([x, y, z])
    return np.array(coordinates)

def write_pdb(file_path, coordinates,chain):
    with open(file_path, 'a') as pdb_file:
        with open('tre-copy.pdb', 'r') as template:
            for line, coord in zip(template, coordinates):
                x_str = f"{coord[0]:8.3f}"
                y_str = f"{coord[1]:8.3f}"
                z_str = f"{coord[2]:8.3f}"
                new_line = f"{line[:25]}{chain}{line[27:31]}{x_str}{y_str}{z_str}{line[54:]}"
                pdb_file.write(new_line)
        pdb_file.write('END\n')
    pdb_file.close

def euler_rotation_matrix(phi, theta, psi):
    R_x = np.array([[1, 0, 0],
                    [0, np.cos(phi), -np.sin(phi)],
                    [0, np.sin(phi), np.cos(phi)]])
    
    R_y = np.array([[np.cos(theta), 0, np.sin(theta)],
                    [0, 1, 0],
                    [-np.sin(theta), 0, np.cos(theta)]])
    
    R_z = np.array([[np.cos(psi), -np.sin(psi), 0],
                    [np.sin(psi), np.cos(psi), 0],
                    [0, 0, 1]])
    
    R = np.dot(R_z, np.dot(R_y, R_x))
    
    return R

def apply_rotation_translation(file_path, phi, theta, psi, translation_vector):
    # Leer el archivo PDB y crear la matriz de coordenadas
    coordinates = read_pdb(file_path)
    print(phi,theta,psi)
    
    # Calcular la matriz de rotación
    R = euler_rotation_matrix(phi, theta, psi)
    
    # Aplicar la rotación a las coordenadas
    rotated_coordinates = np.dot(R, coordinates.T).T
    
    # Aplicar la translación a las coordenadas rotadas
    translated_coordinates = rotated_coordinates + translation_vector
    
    return translated_coordinates

# # Ángulos de Euler originales
# phi = np.pi / 4  # Ángulo de Euler phi (en radianes)
# theta = np.pi / 3  # Ángulo de Euler theta (en radianes)
# psi = np.pi / 6  # Ángulo de Euler psi (en radianes)

# # Vector de translación para cada molécula
# translation_vectors = [
#     np.array([10.0, 10.0, 10.0]),
#     np.array([20.0, 20.0, 20.0]),
#     np.array([30.0, 30.0, 30.0]),
#     np.array([40.0, 40.0, 40.0]),
#     np.array([50.0, 50.0, 50.0]),
#     np.array([60.0, 60.0, 60.0]),
#     np.array([70.0, 70.0, 70.0]),
#     np.array([80.0, 80.0, 80.0]),
#     np.array([90.0, 90.0, 90.0]),
#     np.array([100.0, 100.0, 100.0])
# ]

import os

# Specify the file path
# Crear 10 archivos PDB nuevos con coordenadas rotadas y transladadas
output_directory = "2tre"
file_path = "rotated_translated2.pdb"
output_file_path = os.path.join(output_directory, file_path)

# Check if the file exists before removing it
if os.path.exists(output_file_path):
    # Remove the file
    os.remove(output_file_path)
    print(f"File '{output_file_path}' has been successfully removed.")
else:
    print(f"File '{output_file_path}' does not exist.")




os.makedirs(output_directory, exist_ok=True)

for i in range(2):
    # Introducir variaciones aleatorias en los ángulos de Euler
    phi_random = np.random.uniform(0, 2*np.pi)  # Variación de +/- 15 grados
    theta_random = np.random.uniform(0,2*np.pi)
    psi_random = np.random.uniform(0,2*np.pi)
    translation_vector=[np.random.uniform(-20,20),np.random.uniform(-20,20),np.random.uniform(-20,20)]
    
    rotated_translated_coordinates = apply_rotation_translation('tre-copy.pdb', phi_random, theta_random, psi_random, translation_vector)
    chain=chr(ord('A') + i )
    write_pdb(output_file_path, rotated_translated_coordinates,chain)
    print(f"Archivo {output_file_path} cadena {chain} creado con éxito.")
# Out:
# File '2tre/rotated_translated2.pdb' does not exist.
# 4.928981854816149 3.528884434296554 2.1209370163705206
# Archivo 2tre/rotated_translated2.pdb cadena A creado con éxito.
# 0.701475234830049 3.572415657685895 0.2781273122320263
# Archivo 2tre/rotated_translated2.pdb cadena B creado con éxito.

# %% [markdown]
# Probem amb 25

# %%
import numpy as np
import os

def read_pdb(file_path):
    coordinates = []
    with open(file_path, 'r') as pdb_file:
        for line in pdb_file:
            if line.startswith('ATOM'):
                x = float(line[30:38])
                y = float(line[38:46])
                z = float(line[46:54])
                coordinates.append([x, y, z])
    return np.array(coordinates)

def write_pdb(file_path, coordinates,chain):
    with open(file_path, 'a') as pdb_file:
        with open('tre-copy.pdb', 'r') as template:
            for line, coord in zip(template, coordinates):
                x_str = f"{coord[0]:8.3f}"
                y_str = f"{coord[1]:8.3f}"
                z_str = f"{coord[2]:8.3f}"
                new_line = f"{line[:25]}{chain}{line[27:31]}{x_str}{y_str}{z_str}{line[54:]}"
                pdb_file.write(new_line)
        pdb_file.write('TER\n')
    pdb_file.close

def euler_rotation_matrix(phi, theta, psi):
    R_x = np.array([[1, 0, 0],
                    [0, np.cos(phi), -np.sin(phi)],
                    [0, np.sin(phi), np.cos(phi)]])
    
    R_y = np.array([[np.cos(theta), 0, np.sin(theta)],
                    [0, 1, 0],
                    [-np.sin(theta), 0, np.cos(theta)]])
    
    R_z = np.array([[np.cos(psi), -np.sin(psi), 0],
                    [np.sin(psi), np.cos(psi), 0],
                    [0, 0, 1]])
    
    R = np.dot(R_z, np.dot(R_y, R_x))
    
    return R

def apply_rotation_translation(file_path, phi, theta, psi, translation_vector):
    # Leer el archivo PDB y crear la matriz de coordenadas
    coordinates = read_pdb(file_path)
    print(phi,theta,psi)
    
    # Calcular la matriz de rotación
    R = euler_rotation_matrix(phi, theta, psi)
    
    # Aplicar la rotación a las coordenadas
    rotated_coordinates = np.dot(R, coordinates.T).T
    
    # Aplicar la translación a las coordenadas rotadas
    translated_coordinates = rotated_coordinates + translation_vector
    
    return translated_coordinates

# # Ángulos de Euler originales
# phi = np.pi / 4  # Ángulo de Euler phi (en radianes)
# theta = np.pi / 3  # Ángulo de Euler theta (en radianes)
# psi = np.pi / 6  # Ángulo de Euler psi (en radianes)

# # Vector de translación para cada molécula
# translation_vectors = [
#     np.array([10.0, 10.0, 10.0]),
#     np.array([20.0, 20.0, 20.0]),
#     np.array([30.0, 30.0, 30.0]),
#     np.array([40.0, 40.0, 40.0]),
#     np.array([50.0, 50.0, 50.0]),
#     np.array([60.0, 60.0, 60.0]),
#     np.array([70.0, 70.0, 70.0]),
#     np.array([80.0, 80.0, 80.0]),
#     np.array([90.0, 90.0, 90.0]),
#     np.array([100.0, 100.0, 100.0])
# ]

import os

# Specify the file path
# Crear 10 archivos PDB nuevos con coordenadas rotadas y transladadas
output_directory = "25tre"
file_path = "rotated_translated25.pdb"
output_file_path = os.path.join(output_directory, file_path)

# Check if the file exists before removing it
if os.path.exists(output_file_path):
    # Remove the file
    os.remove(output_file_path)
    print(f"File '{output_file_path}' has been successfully removed.")
else:
    print(f"File '{output_file_path}' does not exist.")




os.makedirs(output_directory, exist_ok=True)

for i in range(25):
    # Introducir variaciones aleatorias en los ángulos de Euler
    phi_random = np.random.uniform(0, 2*np.pi)  # Variación de +/- 15 grados
    theta_random = np.random.uniform(0,2*np.pi)
    psi_random = np.random.uniform(0,2*np.pi)
    translation_vector=[np.random.uniform(-20,20),np.random.uniform(-20,20),np.random.uniform(-20,20)]
    
    rotated_translated_coordinates = apply_rotation_translation('tre-copy.pdb', phi_random, theta_random, psi_random, translation_vector)
    chain=chr(ord('A') + i )
    write_pdb(output_file_path, rotated_translated_coordinates,chain)
    print(f"Archivo {output_file_path} cadena {chain} creado con éxito.")
# Out:
# File '25tre/rotated_translated25.pdb' has been successfully removed.
# 0.8182295880664706 4.973100125574415 0.25722170101973396
# Archivo 25tre/rotated_translated25.pdb cadena A creado con éxito.
# 1.454764175476254 5.617989676451184 0.9228534846501666
# Archivo 25tre/rotated_translated25.pdb cadena B creado con éxito.
# 5.935212594437573 4.45174154786541 5.478513428205729
# Archivo 25tre/rotated_translated25.pdb cadena C creado con éxito.
# 4.637281305781233 1.428593619243112 1.2621693962835945
# Archivo 25tre/rotated_translated25.pdb cadena D creado con éxito.
# 6.216632376966413 3.087982726296974 1.674593536997951
# Archivo 25tre/rotated_translated25.pdb cadena E creado con éxito.
# 3.3129199492064125 3.8575724855864943 5.590352312432543
# Archivo 25tre/rotated_translated25.pdb cadena F creado con éxito.
# 5.505381508352309 4.6775244025880856 2.2228618386533925
# Archivo 25tre/rotated_translated25.pdb cadena G creado con éxito.
# 4.971812052217597 5.477079295394743 3.712603162536422
# Archivo 25tre/rotated_translated25.pdb cadena H creado con éxito.
# 1.5830955903816866 4.35584983089336 0.8493228252194499
# Archivo 25tre/rotated_translated25.pdb cadena I creado con éxito.
# 1.9840799644671316 2.583936397572391 2.3587946757412257
# Archivo 25tre/rotated_translated25.pdb cadena J creado con éxito.
# 0.024295433976264196 1.4083236896626814 2.004656118802085
# Archivo 25tre/rotated_translated25.pdb cadena K creado con éxito.
# 5.617806949734739 3.4072513236701076 0.5419695428621232
# Archivo 25tre/rotated_translated25.pdb cadena L creado con éxito.
# 5.398600879134221 2.9241870985826797 5.95511992788094
# Archivo 25tre/rotated_translated25.pdb cadena M creado con éxito.
# 0.8164923862176893 1.86038019739822 0.7050279882378344
# Archivo 25tre/rotated_translated25.pdb cadena N creado con éxito.
# 0.5444752761748365 4.77968800046753 2.187219526340721
# Archivo 25tre/rotated_translated25.pdb cadena O creado con éxito.
# 1.8387879728822467 4.919330227328006 0.39889600221244675
# Archivo 25tre/rotated_translated25.pdb cadena P creado con éxito.
# 1.6520662352666837 4.46071249339129 3.9613929956724427
# Archivo 25tre/rotated_translated25.pdb cadena Q creado con éxito.
# 1.7314870399848157 0.7974520920294599 1.1197793566478313
# Archivo 25tre/rotated_translated25.pdb cadena R creado con éxito.
# 1.613458527003438 2.9829862772777416 2.210911756839462
# Archivo 25tre/rotated_translated25.pdb cadena S creado con éxito.
# 5.618754326968195 3.638401456470752 3.640796961714601
# Archivo 25tre/rotated_translated25.pdb cadena T creado con éxito.
# 0.9834702811234154 0.8499270574347283 3.773453788309046
# Archivo 25tre/rotated_translated25.pdb cadena U creado con éxito.
# 4.976768411036232 3.943445209002844 3.379837815225959
# Archivo 25tre/rotated_translated25.pdb cadena V creado con éxito.
# 2.7675833176558693 3.764126325886271 4.14185670694227
# Archivo 25tre/rotated_translated25.pdb cadena W creado con éxito.
# 4.522870403173874 3.9617876173322673 1.1914275495068354
# Archivo 25tre/rotated_translated25.pdb cadena X creado con éxito.
# 1.1496848440503884 3.589845841939249 1.1783106895163133
# Archivo 25tre/rotated_translated25.pdb cadena Y creado con éxito.

# %% [markdown]
# Per últim ho fem amb 100

# %%
import numpy as np
import os

def read_pdb(file_path):
    coordinates = []
    with open(file_path, 'r') as pdb_file:
        for line in pdb_file:
            if line.startswith('ATOM'):
                x = float(line[30:38])
                y = float(line[38:46])
                z = float(line[46:54])
                coordinates.append([x, y, z])
    return np.array(coordinates)

def write_pdb(file_path, coordinates,chain):
    with open(file_path, 'a') as pdb_file:
        with open('tre-copy.pdb', 'r') as template:
            for line, coord in zip(template, coordinates):
                x_str = f"{coord[0]:8.3f}"
                y_str = f"{coord[1]:8.3f}"
                z_str = f"{coord[2]:8.3f}"
                new_line = f"{line[:25]}{chain}{line[27:31]}{x_str}{y_str}{z_str}{line[54:]}"
                pdb_file.write(new_line)
        pdb_file.write('END\n')
    pdb_file.close

def euler_rotation_matrix(phi, theta, psi):
    R_x = np.array([[1, 0, 0],
                    [0, np.cos(phi), -np.sin(phi)],
                    [0, np.sin(phi), np.cos(phi)]])
    
    R_y = np.array([[np.cos(theta), 0, np.sin(theta)],
                    [0, 1, 0],
                    [-np.sin(theta), 0, np.cos(theta)]])
    
    R_z = np.array([[np.cos(psi), -np.sin(psi), 0],
                    [np.sin(psi), np.cos(psi), 0],
                    [0, 0, 1]])
    
    R = np.dot(R_z, np.dot(R_y, R_x))
    
    return R

def apply_rotation_translation(file_path, phi, theta, psi, translation_vector):
    # Leer el archivo PDB y crear la matriz de coordenadas
    coordinates = read_pdb(file_path)
    print(phi,theta,psi)
    
    # Calcular la matriz de rotación
    R = euler_rotation_matrix(phi, theta, psi)
    
    # Aplicar la rotación a las coordenadas
    rotated_coordinates = np.dot(R, coordinates.T).T
    
    # Aplicar la translación a las coordenadas rotadas
    translated_coordinates = rotated_coordinates + translation_vector
    
    return translated_coordinates

# # Ángulos de Euler originales
# phi = np.pi / 4  # Ángulo de Euler phi (en radianes)
# theta = np.pi / 3  # Ángulo de Euler theta (en radianes)
# psi = np.pi / 6  # Ángulo de Euler psi (en radianes)

# # Vector de translación para cada molécula
# translation_vectors = [
#     np.array([10.0, 10.0, 10.0]),
#     np.array([20.0, 20.0, 20.0]),
#     np.array([30.0, 30.0, 30.0]),
#     np.array([40.0, 40.0, 40.0]),
#     np.array([50.0, 50.0, 50.0]),
#     np.array([60.0, 60.0, 60.0]),
#     np.array([70.0, 70.0, 70.0]),
#     np.array([80.0, 80.0, 80.0]),
#     np.array([90.0, 90.0, 90.0]),
#     np.array([100.0, 100.0, 100.0])
# ]

import os

# Specify the file path
# Crear 10 archivos PDB nuevos con coordenadas rotadas y transladadas
output_directory = "100tre"
file_path = "rotated_translated100.pdb"
output_file_path = os.path.join(output_directory, file_path)

# Check if the file exists before removing it
if os.path.exists(output_file_path):
    # Remove the file
    os.remove(output_file_path)
    print(f"File '{output_file_path}' has been successfully removed.")
else:
    print(f"File '{output_file_path}' does not exist.")

def main():
    output_directory = "100tre"
    os.makedirs(output_directory, exist_ok=True)

if __name__ == "__main__":
    main()
os.makedirs(output_directory, exist_ok=True)

for i in range(100):
    # Introducir variaciones aleatorias en los ángulos de Euler
    phi_random = np.random.uniform(0, 2*np.pi)  # Variación de +/- 15 grados
    theta_random = np.random.uniform(0,2*np.pi)
    psi_random = np.random.uniform(0,2*np.pi)
    translation_vector=[np.random.uniform(-20,20),np.random.uniform(-20,20),np.random.uniform(-20,20)]
    
    rotated_translated_coordinates = apply_rotation_translation('tre-copy.pdb', phi_random, theta_random, psi_random, translation_vector)
    chain=chr(ord('A') + i )
    write_pdb(output_file_path, rotated_translated_coordinates,chain)
    print(f"Archivo {output_file_path} cadena {chain} creado con éxito.")
# Out:
# File '100tre/rotated_translated100.pdb' does not exist.
# 2.9736920261570727 1.1991143022814272 2.8724122285378426
# Archivo 100tre/rotated_translated100.pdb cadena A creado con éxito.
# 4.652041216288577 2.2951689760328775 5.605175074649089
# Archivo 100tre/rotated_translated100.pdb cadena B creado con éxito.
# 5.239968111162267 4.644629154450813 0.5994947009775488
# Archivo 100tre/rotated_translated100.pdb cadena C creado con éxito.
# 3.8350637825926217 4.233440984020956 1.1724722699154175
# Archivo 100tre/rotated_translated100.pdb cadena D creado con éxito.
# 1.758921104311507 5.677133934942454 1.1215055681662467
# Archivo 100tre/rotated_translated100.pdb cadena E creado con éxito.
# 3.4743401402449074 2.123100800228194 5.900634650727086
# Archivo 100tre/rotated_translated100.pdb cadena F creado con éxito.
# 1.2934716462600597 5.343374582025807 2.48133867661832
# Archivo 100tre/rotated_translated100.pdb cadena G creado con éxito.
# 2.02099815814637 0.27262365261792376 0.04372766814258996
# Archivo 100tre/rotated_translated100.pdb cadena H creado con éxito.
# 2.2655343338695717 4.2789283739484 5.867045374846266
# Archivo 100tre/rotated_translated100.pdb cadena I creado con éxito.
# 5.862742406692324 2.9713027668149095 1.146594946806745
# Archivo 100tre/rotated_translated100.pdb cadena J creado con éxito.
# 3.070376164580559 4.176340891290723 4.167524107419355
# Archivo 100tre/rotated_translated100.pdb cadena K creado con éxito.
# 4.075076334269941 4.737774184554679 0.1762411359033317
# Archivo 100tre/rotated_translated100.pdb cadena L creado con éxito.
# 4.073343827416725 3.8413303758312045 5.384806274751528
# Archivo 100tre/rotated_translated100.pdb cadena M creado con éxito.
# 5.7065767120913575 0.6143292093249977 6.238187529159075
# Archivo 100tre/rotated_translated100.pdb cadena N creado con éxito.
# 4.241646633973744 6.261735834336275 0.02235355778458928
# Archivo 100tre/rotated_translated100.pdb cadena O creado con éxito.
# 2.683808316607553 4.488762346418986 2.6245996913554546
# Archivo 100tre/rotated_translated100.pdb cadena P creado con éxito.
# 2.3240824231905943 3.2471031162372084 0.00524996839607912
# Archivo 100tre/rotated_translated100.pdb cadena Q creado con éxito.
# 5.407715528373794 3.1251199815244703 4.332343735850006
# Archivo 100tre/rotated_translated100.pdb cadena R creado con éxito.
# 1.9324391076976983 3.3561349158264537 3.946953078018907
# Archivo 100tre/rotated_translated100.pdb cadena S creado con éxito.
# 1.786676933957453 0.8902053003200536 0.8933961197822323
# Archivo 100tre/rotated_translated100.pdb cadena T creado con éxito.
# 2.750221890032877 6.19579023230575 1.6633766887046524
# Archivo 100tre/rotated_translated100.pdb cadena U creado con éxito.
# 2.176254226028516 1.5499844163026892 3.593735169694812
# Archivo 100tre/rotated_translated100.pdb cadena V creado con éxito.
# 1.3417080060642141 6.06378953117663 0.5410175270929989
# Archivo 100tre/rotated_translated100.pdb cadena W creado con éxito.
# 3.2281171612034965 1.7788945956634286 4.646989599278542
# Archivo 100tre/rotated_translated100.pdb cadena X creado con éxito.
# 0.925904676689023 0.7735089523250434 2.521222672467887
# Archivo 100tre/rotated_translated100.pdb cadena Y creado con éxito.
# 1.2016346541776306 1.7668504471692683 3.803968976693616
# Archivo 100tre/rotated_translated100.pdb cadena Z creado con éxito.
# 0.28192983166543234 1.793425202466135 1.705522699176713
# Archivo 100tre/rotated_translated100.pdb cadena [ creado con éxito.
# 2.5925391290365347 5.921090976311046 5.132428681961197
# Archivo 100tre/rotated_translated100.pdb cadena \ creado con éxito.
# 1.720683192851556 4.307825222136508 5.14458859162299
# Archivo 100tre/rotated_translated100.pdb cadena ] creado con éxito.
# 4.915186615462112 1.7678790069733807 1.5715417884226162
# Archivo 100tre/rotated_translated100.pdb cadena ^ creado con éxito.
# 3.355703271469507 5.356107106539361 5.948411929741502
# Archivo 100tre/rotated_translated100.pdb cadena _ creado con éxito.
# 3.2978748619475793 4.002587615656893 0.3652193692227694
# Archivo 100tre/rotated_translated100.pdb cadena ` creado con éxito.
# 2.1131730077729904 0.1905320413063607 3.1133073682418018
# Archivo 100tre/rotated_translated100.pdb cadena a creado con éxito.
# 6.141724641811665 2.8846719050321026 3.3717769779473468
# Archivo 100tre/rotated_translated100.pdb cadena b creado con éxito.
# 4.861599243547854 0.3736300789511817 1.15132981011628
# Archivo 100tre/rotated_translated100.pdb cadena c creado con éxito.
# 2.5910638880538337 1.3761889767339102 5.7879344002282584
# Archivo 100tre/rotated_translated100.pdb cadena d creado con éxito.
# 0.22734565714984445 3.9367158033441543 4.007094897354337
# Archivo 100tre/rotated_translated100.pdb cadena e creado con éxito.
# 0.18929523617850527 2.080322130563628 3.5060884132104078
# Archivo 100tre/rotated_translated100.pdb cadena f creado con éxito.
# 3.856659648129631 2.3090245801819815 5.032648549694052
# Archivo 100tre/rotated_translated100.pdb cadena g creado con éxito.
# 3.1029120631843305 4.613038369601608 2.6078123231107733
# Archivo 100tre/rotated_translated100.pdb cadena h creado con éxito.
# 5.3843781297074695 6.27320276365489 4.164534544044801
# Archivo 100tre/rotated_translated100.pdb cadena i creado con éxito.
# 4.18418361366276 3.300264433109502 0.16936001789638763
# Archivo 100tre/rotated_translated100.pdb cadena j creado con éxito.
# 4.690159874511767 0.6920343741946936 4.970172506339191
# Archivo 100tre/rotated_translated100.pdb cadena k creado con éxito.
# 6.031268942951224 5.765824702588466 3.7529855268538794
# Archivo 100tre/rotated_translated100.pdb cadena l creado con éxito.
# 2.239754354551283 1.142167738442229 3.6248592435422036
# Archivo 100tre/rotated_translated100.pdb cadena m creado con éxito.
# 4.728328648497669 0.2530112037259797 0.4261103288356185
# Archivo 100tre/rotated_translated100.pdb cadena n creado con éxito.
# 0.44923188781439344 4.461828704992912 4.261164550519861
# Archivo 100tre/rotated_translated100.pdb cadena o creado con éxito.
# 5.509437083417262 5.3762205203667985 1.9865838231880677
# Archivo 100tre/rotated_translated100.pdb cadena p creado con éxito.
# 6.210306095576938 6.213368192274129 5.9742188427390355
# Archivo 100tre/rotated_translated100.pdb cadena q creado con éxito.
# 5.206275305895801 5.6848579082385395 3.015969518823921
# Archivo 100tre/rotated_translated100.pdb cadena r creado con éxito.
# 2.2492641052954494 6.279860293820577 4.454684042261262
# Archivo 100tre/rotated_translated100.pdb cadena s creado con éxito.
# 0.6778532465771646 5.295376893386924 5.348674916857666
# Archivo 100tre/rotated_translated100.pdb cadena t creado con éxito.
# 2.825625514221488 1.7401200064234008 1.8295205707144828
# Archivo 100tre/rotated_translated100.pdb cadena u creado con éxito.
# 4.628862761789082 4.00424767246362 0.23160756486346704
# Archivo 100tre/rotated_translated100.pdb cadena v creado con éxito.
# 5.880685966343229 2.9738147592548314 1.666541007439354
# Archivo 100tre/rotated_translated100.pdb cadena w creado con éxito.
# 0.29670579519591417 0.3479349937959002 4.95339754167896
# Archivo 100tre/rotated_translated100.pdb cadena x creado con éxito.
# 2.9125751695045423 0.54204765250313 0.3725006372714953
# Archivo 100tre/rotated_translated100.pdb cadena y creado con éxito.
# 2.322137341956959 4.348497247991732 4.887303694645526
# Archivo 100tre/rotated_translated100.pdb cadena z creado con éxito.
# 6.027895752963846 3.855065864794131 4.125281073328509
# Archivo 100tre/rotated_translated100.pdb cadena { creado con éxito.
# 4.552578801153354 5.239354232568669 2.4303577118609243
# Archivo 100tre/rotated_translated100.pdb cadena | creado con éxito.
# 4.054358708507086 6.113545647424669 6.068546662019095
# Archivo 100tre/rotated_translated100.pdb cadena } creado con éxito.
# 0.2543183600428453 4.3287643379180905 5.60296861837626
# Archivo 100tre/rotated_translated100.pdb cadena ~ creado con éxito.
# 3.8928039696236105 2.997937165470175 6.013640533562524
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 6.015172595551738 1.0186650108847297 3.019762501550505
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 5.4499188724197385 2.4000893062363358 5.0251362447597225
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 4.095268654752377 3.243685336000637 1.6369766163631978
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 0.5904120841764331 3.9407315525404205 2.9670364287299535
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 0.5914619694684826 2.990542648035019 4.28707150836757
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 4.748765137632276 1.4668266990389671 5.66451826292321
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 1.7584949538430743 0.587667345646171 4.529292869023413
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 5.917369032300947 1.2164132710351003 3.1655565212796857
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 1.3545201868158299 5.193282653604765 3.9124078675806833
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 5.2764029418486595 3.600659768258821 3.842416599445409
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 3.791750274886452 1.9853996077816405 1.1418934163212588
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 1.6971367669696849 1.9501707991996116 4.065534644137591
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 4.924195969721718 4.331888004297532 5.1686673196761355
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 3.24583414127454 4.032520736080033 5.764346122800318
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 4.299096743426563 3.167559110106971 5.570814939490057
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 0.12008950404007072 0.5877528546950441 4.361157297042769
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 5.202049302471225 2.6457647693922235 5.996450635955248
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 4.42137811771246 2.8735093647950047 2.445163688446909
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 1.3392967429572908 1.8073724205119128 0.43098922586210087
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 5.01697610559128 1.7148877084292369 1.6197692677920204
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 0.17755535053548097 2.250440025188548 2.0238734860830108
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 1.6360321744918251 1.9629070310010766 4.5864861397837045
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 1.2349246135656031 0.21694476764118353 0.681021654350083
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 3.112331891116135 1.0113017297733495 3.3317735128910475
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 2.91721939936885 1.2785438424528595 0.23019818675806145
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 4.2693745602546445 5.905560879398506 0.3948844836700344
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 2.8912733296075888 1.5692087324090669 4.127228808423869
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 3.2255867931401316 2.222523602131163 2.6874556316603027
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 4.479662492257459 0.3426541550253907 2.0484490602885295
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 3.978139378255266 4.701848535771509 2.2205131477984557
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 5.324611047573731 1.0654202508708284 5.251185385851848
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 1.9091791484643508 6.150990456211947 3.5434604078796004
# Archivo 100tre/rotated_translated100.pdb cadena  creado con éxito.
# 1.092776896061934 2.491167297252476 1.6505765858152708
# Archivo 100tre/rotated_translated100.pdb cadena   creado con éxito.
# 1.4756773656295241 2.994265373983451 2.2319534236953777
# Archivo 100tre/rotated_translated100.pdb cadena ¡ creado con éxito.
# 4.1377965282753895 0.023093589676427474 4.564118578409503
# Archivo 100tre/rotated_translated100.pdb cadena ¢ creado con éxito.
# 6.13649503505541 3.215966269001045 4.84458747278867
# Archivo 100tre/rotated_translated100.pdb cadena £ creado con éxito.
# 0.7695436072326781 2.3189823861128276 6.04071235027352
# Archivo 100tre/rotated_translated100.pdb cadena ¤ creado con éxito.

# %%
import numpy as np
import os

def read_pdb(file_path):
    coordinates = []
    with open(file_path, 'r') as pdb_file:
        for line in pdb_file:
            if line.startswith('ATOM'):
                x = float(line[30:38])
                y = float(line[38:46])
                z = float(line[46:54])
                coordinates.append([x, y, z])
    return np.array(coordinates)

def write_pdb(file_path, coordinates,chain):
    with open(file_path, 'a') as pdb_file:
        with open('tre-copy.pdb', 'r') as template:
            for line, coord in zip(template, coordinates):
                x_str = f"{coord[0]:8.3f}"
                y_str = f"{coord[1]:8.3f}"
                z_str = f"{coord[2]:8.3f}"
                new_line = f"{line[:25]}{chain}{line[27:31]}{x_str}{y_str}{z_str}{line[54:]}"
                pdb_file.write(new_line)
        pdb_file.write('END\n')
    pdb_file.close

def euler_rotation_matrix(phi, theta, psi):
    R_x = np.array([[1, 0, 0],
                    [0, np.cos(phi), -np.sin(phi)],
                    [0, np.sin(phi), np.cos(phi)]])
    
    R_y = np.array([[np.cos(theta), 0, np.sin(theta)],
                    [0, 1, 0],
                    [-np.sin(theta), 0, np.cos(theta)]])
    
    R_z = np.array([[np.cos(psi), -np.sin(psi), 0],
                    [np.sin(psi), np.cos(psi), 0],
                    [0, 0, 1]])
    
    R = np.dot(R_z, np.dot(R_y, R_x))
    
    return R

def apply_rotation_translation(file_path, phi, theta, psi, translation_vector):
    # Leer el archivo PDB y crear la matriz de coordenadas
    coordinates = read_pdb(file_path)
    print(phi,theta,psi)
    
    # Calcular la matriz de rotación
    R = euler_rotation_matrix(phi, theta, psi)
    
    # Aplicar la rotación a las coordenadas
    rotated_coordinates = np.dot(R, coordinates.T).T
    
    # Aplicar la translación a las coordenadas rotadas
    translated_coordinates = rotated_coordinates + translation_vector
    
    return translated_coordinates

# # Ángulos de Euler originales
# phi = np.pi / 4  # Ángulo de Euler phi (en radianes)
# theta = np.pi / 3  # Ángulo de Euler theta (en radianes)
# psi = np.pi / 6  # Ángulo de Euler psi (en radianes)

# # Vector de translación para cada molécula
# translation_vectors = [
#     np.array([10.0, 10.0, 10.0]),
#     np.array([20.0, 20.0, 20.0]),
#     np.array([30.0, 30.0, 30.0]),
#     np.array([40.0, 40.0, 40.0]),
#     np.array([50.0, 50.0, 50.0]),
#     np.array([60.0, 60.0, 60.0]),
#     np.array([70.0, 70.0, 70.0]),
#     np.array([80.0, 80.0, 80.0]),
#     np.array([90.0, 90.0, 90.0]),
#     np.array([100.0, 100.0, 100.0])
# ]

import os

# Specify the file path
# Crear 10 archivos PDB nuevos con coordenadas rotadas y transladadas
output_directory = "102tre"
file_path = "rotated_translated102.pdb"
output_file_path = os.path.join(output_directory, file_path)

# Check if the file exists before removing it
if os.path.exists(output_file_path):
    # Remove the file
    os.remove(output_file_path)
    print(f"File '{output_file_path}' has been successfully removed.")
else:
    print(f"File '{output_file_path}' does not exist.")

def main():
    output_directory = "102tre"
    os.makedirs(output_directory, exist_ok=True)

if __name__ == "__main__":
    main()
os.makedirs(output_directory, exist_ok=True)

for i in range(100):
    # Introducir variaciones aleatorias en los ángulos de Euler
    phi_random = np.random.uniform(0, 2*np.pi)  # Variación de +/- 15 grados
    theta_random = np.random.uniform(0,2*np.pi)
    psi_random = np.random.uniform(0,2*np.pi)
    translation_vector=[np.random.uniform(-20,20),np.random.uniform(-20,20),np.random.uniform(-20,20)]
    
    rotated_translated_coordinates = apply_rotation_translation('tre-copy.pdb', phi_random, theta_random, psi_random, translation_vector)
    chain=chr(ord('A') + i )
    write_pdb(output_file_path, rotated_translated_coordinates,chain)
    print(f"Archivo {output_file_path} cadena {chain} creado con éxito.")
# Out:
# File '102tre/rotated_translated102.pdb' does not exist.
# 3.1090621305098267 1.573145977808182 0.7410507465856394
# Archivo 102tre/rotated_translated102.pdb cadena A creado con éxito.
# 1.608802983381072 0.801039990535773 4.0654017721786015
# Archivo 102tre/rotated_translated102.pdb cadena B creado con éxito.
# 0.1623646145675489 4.156374273980816 2.358388439193126
# Archivo 102tre/rotated_translated102.pdb cadena C creado con éxito.
# 3.1150298977588142 4.4247469237312655 3.0709204611279173
# Archivo 102tre/rotated_translated102.pdb cadena D creado con éxito.
# 0.17036380705736337 3.7457396556664344 5.931761081315371
# Archivo 102tre/rotated_translated102.pdb cadena E creado con éxito.
# 0.11485237252457113 4.79273916238641 0.8305906253713471
# Archivo 102tre/rotated_translated102.pdb cadena F creado con éxito.
# 0.24186907127408888 2.7360232020092066 2.7398113504719652
# Archivo 102tre/rotated_translated102.pdb cadena G creado con éxito.
# 3.2158118361393293 5.258909607659827 3.4874681437099992
# Archivo 102tre/rotated_translated102.pdb cadena H creado con éxito.
# 1.3182748022659792 4.6559946195228505 5.175515007353728
# Archivo 102tre/rotated_translated102.pdb cadena I creado con éxito.
# 5.041118472175296 4.8233018237192296 0.7955735235440446
# Archivo 102tre/rotated_translated102.pdb cadena J creado con éxito.
# 4.529506629800135 0.6319746175757823 4.528142986686709
# Archivo 102tre/rotated_translated102.pdb cadena K creado con éxito.
# 3.8435293061264613 3.1556865897002444 2.7086109729946535
# Archivo 102tre/rotated_translated102.pdb cadena L creado con éxito.
# 3.1597473924448427 5.471074933055548 3.136146660150712
# Archivo 102tre/rotated_translated102.pdb cadena M creado con éxito.
# 1.3954798389848424 0.15481556433611082 0.5538961381959312
# Archivo 102tre/rotated_translated102.pdb cadena N creado con éxito.
# 4.042760137829127 3.5893924911659 4.44123470394995
# Archivo 102tre/rotated_translated102.pdb cadena O creado con éxito.
# 0.442993880875147 0.42614285583962613 6.241530944543222
# Archivo 102tre/rotated_translated102.pdb cadena P creado con éxito.
# 6.030147110307153 5.443544721945385 0.725866381179404
# Archivo 102tre/rotated_translated102.pdb cadena Q creado con éxito.
# 6.139741369255865 2.390511422640636 2.677114352468901
# Archivo 102tre/rotated_translated102.pdb cadena R creado con éxito.
# 5.039266524282441 5.659193706091439 1.8393686224773267
# Archivo 102tre/rotated_translated102.pdb cadena S creado con éxito.
# 0.3887559670708417 1.7108454648439821 2.092034469427265
# Archivo 102tre/rotated_translated102.pdb cadena T creado con éxito.
# 2.8486295638668104 4.1641648791019525 2.0132526781567264
# Archivo 102tre/rotated_translated102.pdb cadena U creado con éxito.
# 2.449830305582955 2.986944310991007 1.6963000179054954
# Archivo 102tre/rotated_translated102.pdb cadena V creado con éxito.
# 1.360414299829028 1.5503484653919288 1.3640986718432775
# Archivo 102tre/rotated_translated102.pdb cadena W creado con éxito.
# 2.3774635116303395 2.158490094544169 0.25385909976801785
# Archivo 102tre/rotated_translated102.pdb cadena X creado con éxito.
# 0.43792856855066614 5.062791843338738 2.8524437097475337
# Archivo 102tre/rotated_translated102.pdb cadena Y creado con éxito.
# 0.7574852391307113 0.4499888138385017 2.976221732088348
# Archivo 102tre/rotated_translated102.pdb cadena Z creado con éxito.
# 2.2294189560290993 0.5672971296716233 3.964924679770192
# Archivo 102tre/rotated_translated102.pdb cadena [ creado con éxito.
# 1.4023803906045018 0.32127409250020195 2.1315413541123918
# Archivo 102tre/rotated_translated102.pdb cadena \ creado con éxito.
# 0.05088419535262352 6.152367053416033 5.5236193290831945
# Archivo 102tre/rotated_translated102.pdb cadena ] creado con éxito.
# 3.1220564158374047 5.004925247578914 5.3113629438655305
# Archivo 102tre/rotated_translated102.pdb cadena ^ creado con éxito.
# 2.007178974076971 1.4501920560051051 0.5438405045120838
# Archivo 102tre/rotated_translated102.pdb cadena _ creado con éxito.
# 1.9648023068853098 1.6342379120797914 2.009241815519295
# Archivo 102tre/rotated_translated102.pdb cadena ` creado con éxito.
# 3.354235801720696 2.976162684330308 3.770645620316053
# Archivo 102tre/rotated_translated102.pdb cadena a creado con éxito.
# 3.8174175496061893 0.5008048174536596 4.8501534251963525
# Archivo 102tre/rotated_translated102.pdb cadena b creado con éxito.
# 3.5244620970098817 3.0652815280474246 3.45408633971083
# Archivo 102tre/rotated_translated102.pdb cadena c creado con éxito.
# 3.2407596526643583 0.03780815276838729 1.9991322773878022
# Archivo 102tre/rotated_translated102.pdb cadena d creado con éxito.
# 6.205284915057943 1.7391912836468388 5.2105739772093
# Archivo 102tre/rotated_translated102.pdb cadena e creado con éxito.
# 1.6309156598907972 2.351055492926871 1.6917708335246964
# Archivo 102tre/rotated_translated102.pdb cadena f creado con éxito.
# 4.773595986519883 5.50281954697906 1.6521232072110983
# Archivo 102tre/rotated_translated102.pdb cadena g creado con éxito.
# 1.9150438821019924 4.133112640793505 0.6188088118190075
# Archivo 102tre/rotated_translated102.pdb cadena h creado con éxito.
# 1.63509850477223 4.552566009282173 0.8334182304588353
# Archivo 102tre/rotated_translated102.pdb cadena i creado con éxito.
# 5.448308822655933 1.7976275070243097 2.877432041477426
# Archivo 102tre/rotated_translated102.pdb cadena j creado con éxito.
# 1.6420667860430036 2.1027924638668356 3.2259264814359203
# Archivo 102tre/rotated_translated102.pdb cadena k creado con éxito.
# 1.287682059647871 6.251035530377108 5.7366780439266165
# Archivo 102tre/rotated_translated102.pdb cadena l creado con éxito.
# 0.6108982123472415 1.7274183093859448 1.579213696302524
# Archivo 102tre/rotated_translated102.pdb cadena m creado con éxito.
# 5.312979174198045 0.8008571999102709 5.706762021151038
# Archivo 102tre/rotated_translated102.pdb cadena n creado con éxito.
# 5.707998750490374 3.545305352109507 5.923936097487181
# Archivo 102tre/rotated_translated102.pdb cadena o creado con éxito.
# 2.980023477627526 5.145940303414725 4.5973828863307125
# Archivo 102tre/rotated_translated102.pdb cadena p creado con éxito.
# 5.665764582190175 2.282031320900369 5.981778468548019
# Archivo 102tre/rotated_translated102.pdb cadena q creado con éxito.
# 0.3781862194789726 0.050560906922133525 0.5035439957945307
# Archivo 102tre/rotated_translated102.pdb cadena r creado con éxito.
# 1.2641388520571075 2.7335318764786436 0.2623116629575034
# Archivo 102tre/rotated_translated102.pdb cadena s creado con éxito.
# 5.538245242721152 4.127178198884883 3.745229393245069
# Archivo 102tre/rotated_translated102.pdb cadena t creado con éxito.
# 2.723507738906621 1.6111582970064569 6.1450146588483365
# Archivo 102tre/rotated_translated102.pdb cadena u creado con éxito.
# 2.2972591544079415 0.661155212076012 1.8046160310517319
# Archivo 102tre/rotated_translated102.pdb cadena v creado con éxito.
# 0.7204745704876712 5.094291996444083 6.1235840817504705
# Archivo 102tre/rotated_translated102.pdb cadena w creado con éxito.
# 0.22888066517572933 3.4023257095199324 6.089057136404249
# Archivo 102tre/rotated_translated102.pdb cadena x creado con éxito.
# 0.5637789868437448 3.1666666413461417 0.7728901666221364
# Archivo 102tre/rotated_translated102.pdb cadena y creado con éxito.
# 2.346987464061377 2.35011719468391 5.6228213549886075
# Archivo 102tre/rotated_translated102.pdb cadena z creado con éxito.
# 4.78437479596436 1.3667124617480264 4.760628028905342
# Archivo 102tre/rotated_translated102.pdb cadena { creado con éxito.
# 4.050986340165961 5.704141649540304 3.2413880338954812
# Archivo 102tre/rotated_translated102.pdb cadena | creado con éxito.
# 0.1427821740306814 1.6996280949429996 1.5098838231802763
# Archivo 102tre/rotated_translated102.pdb cadena } creado con éxito.
# 2.1573564597944914 4.162092540316621 2.381492648966655
# Archivo 102tre/rotated_translated102.pdb cadena ~ creado con éxito.
# 1.3702313719031176 6.19981661203702 2.4337885687983523
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 0.1614844159245857 0.37330400349207704 3.5662740716920283
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 3.0180561240849424 2.2194159232022326 1.6997058892908237
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 3.9698013017337406 4.120439857877662 5.625570669162312
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 4.1092217506331155 6.250332978991004 4.281452031472285
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 0.205260257177204 2.6685664747864113 5.611170471882949
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 3.8323965649208387 4.461041725381639 1.870585098437811
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 6.178914015308141 1.2874796817422112 6.028746680119828
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 1.5613867960432508 2.3557033991441507 6.255415688470022
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 2.039362955814733 3.0916142251670107 0.10190100487471683
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 4.706166220500917 4.491447317648679 1.207163572374928
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 3.530012750535507 0.8997494922844349 1.6610885593513363
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 5.590106774942212 0.6895279080834367 6.126005636283995
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 1.8163874866873693 3.4879692827819824 0.4390687434873758
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 3.0012200249779295 4.26590572169196 3.190858948110883
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 0.1152662664740526 4.308028495649949 5.540153284718227
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 0.4981879820640377 3.9614254322994125 1.6726915268900084
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 4.840703327078124 6.102689522694023 5.501286991030481
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 4.148642686494266 5.738062033320331 4.8440304125036455
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 0.04121671101605412 4.09223631382729 5.103397183998882
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 5.371673591960792 1.5638591569066502 5.2251960098660675
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 1.0011751000283509 1.8707199587196044 4.942603809578638
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 5.000346868700891 0.4449166000042057 4.207242175766398
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 1.7347993011065557 4.567159525984523 1.7229071866685146
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 1.739588675747981 3.7171786268729248 3.416085195513053
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 1.1090903989907932 5.822390204710574 3.00265265672493
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 6.215404607668839 1.1143549572080833 2.939434040097683
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 3.7183167638373527 3.1352687554909915 1.0397132976619663
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 1.3497248763524459 3.6031905950343392 1.041983261694971
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 2.618168483614377 3.275857744484656 3.859850748189694
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 0.6894327733129788 4.665954878161721 4.442460750206853
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 0.23066804141715552 6.003121481301068 3.6281202644111663
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 3.580396104783029 0.6940125806007734 1.7338620393361115
# Archivo 102tre/rotated_translated102.pdb cadena  creado con éxito.
# 3.217399368291679 4.769454565316121 3.8188072436193448
# Archivo 102tre/rotated_translated102.pdb cadena   creado con éxito.
# 0.6303099303556938 5.28462148785505 2.7341578112028735
# Archivo 102tre/rotated_translated102.pdb cadena ¡ creado con éxito.
# 1.2682194920314114 6.055614685437162 0.9190798890450628
# Archivo 102tre/rotated_translated102.pdb cadena ¢ creado con éxito.
# 1.6084383790240093 4.7332537877264205 0.5284034152001954
# Archivo 102tre/rotated_translated102.pdb cadena £ creado con éxito.
# 3.422027487264115 0.1387575957233755 0.24856353631527256
# Archivo 102tre/rotated_translated102.pdb cadena ¤ creado con éxito.

# %%
import numpy as np
import os

def read_pdb(file_path):
    coordinates = []
    with open(file_path, 'r') as pdb_file:
        for line in pdb_file:
            if line.startswith('ATOM'):
                x = float(line[30:38])
                y = float(line[38:46])
                z = float(line[46:54])
                coordinates.append([x, y, z])
    return np.array(coordinates)

def write_pdb(file_path, coordinates,chain):
    with open(file_path, 'a') as pdb_file:
        with open('tre-copy.pdb', 'r') as template:
            for line, coord in zip(template, coordinates):
                x_str = f"{coord[0]:8.3f}"
                y_str = f"{coord[1]:8.3f}"
                z_str = f"{coord[2]:8.3f}"
                new_line = f"{line[:25]}{chain}{line[27:31]}{x_str}{y_str}{z_str}{line[54:]}"
                pdb_file.write(new_line)
        pdb_file.write('END\n')
    pdb_file.close

def euler_rotation_matrix(phi, theta, psi):
    R_x = np.array([[1, 0, 0],
                    [0, np.cos(phi), -np.sin(phi)],
                    [0, np.sin(phi), np.cos(phi)]])
    
    R_y = np.array([[np.cos(theta), 0, np.sin(theta)],
                    [0, 1, 0],
                    [-np.sin(theta), 0, np.cos(theta)]])
    
    R_z = np.array([[np.cos(psi), -np.sin(psi), 0],
                    [np.sin(psi), np.cos(psi), 0],
                    [0, 0, 1]])
    
    R = np.dot(R_z, np.dot(R_y, R_x))
    
    return R

def apply_rotation_translation(file_path, phi, theta, psi, translation_vector):
    # Leer el archivo PDB y crear la matriz de coordenadas
    coordinates = read_pdb(file_path)
    print(phi,theta,psi)
    
    # Calcular la matriz de rotación
    R = euler_rotation_matrix(phi, theta, psi)
    
    # Aplicar la rotación a las coordenadas
    rotated_coordinates = np.dot(R, coordinates.T).T
    
    # Aplicar la translación a las coordenadas rotadas
    translated_coordinates = rotated_coordinates + translation_vector
    
    return translated_coordinates

# # Ángulos de Euler originales
# phi = np.pi / 4  # Ángulo de Euler phi (en radianes)
# theta = np.pi / 3  # Ángulo de Euler theta (en radianes)
# psi = np.pi / 6  # Ángulo de Euler psi (en radianes)

# # Vector de translación para cada molécula
# translation_vectors = [
#     np.array([10.0, 10.0, 10.0]),
#     np.array([20.0, 20.0, 20.0]),
#     np.array([30.0, 30.0, 30.0]),
#     np.array([40.0, 40.0, 40.0]),
#     np.array([50.0, 50.0, 50.0]),
#     np.array([60.0, 60.0, 60.0]),
#     np.array([70.0, 70.0, 70.0]),
#     np.array([80.0, 80.0, 80.0]),
#     np.array([90.0, 90.0, 90.0]),
#     np.array([100.0, 100.0, 100.0])
# ]

import os

# Specify the file path
# Crear 10 archivos PDB nuevos con coordenadas rotadas y transladadas
output_directory = "103tre"
file_path = "rotated_translated103.pdb"
output_file_path = os.path.join(output_directory, file_path)

# Check if the file exists before removing it
if os.path.exists(output_file_path):
    # Remove the file
    os.remove(output_file_path)
    print(f"File '{output_file_path}' has been successfully removed.")
else:
    print(f"File '{output_file_path}' does not exist.")

def main():
    output_directory = "103tre"
    os.makedirs(output_directory, exist_ok=True)

if __name__ == "__main__":
    main()
os.makedirs(output_directory, exist_ok=True)

for i in range(100):
    # Introducir variaciones aleatorias en los ángulos de Euler
    phi_random = np.random.uniform(0, 2*np.pi)  # Variación de +/- 15 grados
    theta_random = np.random.uniform(0,2*np.pi)
    psi_random = np.random.uniform(0,2*np.pi)
    translation_vector=[np.random.uniform(-20,20),np.random.uniform(-20,20),np.random.uniform(-20,20)]
    
    rotated_translated_coordinates = apply_rotation_translation('tre-copy.pdb', phi_random, theta_random, psi_random, translation_vector)
    chain=chr(ord('A') + i )
    write_pdb(output_file_path, rotated_translated_coordinates,chain)
    print(f"Archivo {output_file_path} cadena {chain} creado con éxito.")
# Out:
# File '103tre/rotated_translated103.pdb' does not exist.
# 3.978522703163145 6.122811642341016 5.645022450492943
# Archivo 103tre/rotated_translated103.pdb cadena A creado con éxito.
# 3.2890861534410005 0.7122201798437122 4.570828966429871
# Archivo 103tre/rotated_translated103.pdb cadena B creado con éxito.
# 2.7537564379729385 2.677653138378302 1.5918586121824538
# Archivo 103tre/rotated_translated103.pdb cadena C creado con éxito.
# 0.7054094534086692 5.955080237561584 4.215502010675237
# Archivo 103tre/rotated_translated103.pdb cadena D creado con éxito.
# 1.5680211840018468 2.217015781643067 2.3285486408375213
# Archivo 103tre/rotated_translated103.pdb cadena E creado con éxito.
# 5.9165752950789 3.008394491541149 3.6062125612724607
# Archivo 103tre/rotated_translated103.pdb cadena F creado con éxito.
# 4.73549073629305 3.7627280594928916 6.2518955378119765
# Archivo 103tre/rotated_translated103.pdb cadena G creado con éxito.
# 2.411539519272444 3.9246651564223245 0.5626413554744756
# Archivo 103tre/rotated_translated103.pdb cadena H creado con éxito.
# 5.53183017263494 1.266710305496341 3.2371607631326738
# Archivo 103tre/rotated_translated103.pdb cadena I creado con éxito.
# 3.8440386206690693 5.209201677448817 2.9886518608346773
# Archivo 103tre/rotated_translated103.pdb cadena J creado con éxito.
# 4.168339119557961 2.779515266521933 4.454065021117713
# Archivo 103tre/rotated_translated103.pdb cadena K creado con éxito.
# 1.011728927833822 4.897507812559137 3.989883679904645
# Archivo 103tre/rotated_translated103.pdb cadena L creado con éxito.
# 3.4239650844426666 4.422000528628183 5.825109464496711
# Archivo 103tre/rotated_translated103.pdb cadena M creado con éxito.
# 0.7332293646801012 5.854137287991586 4.601626778832606
# Archivo 103tre/rotated_translated103.pdb cadena N creado con éxito.
# 1.2271646921797572 4.995363863379594 5.7861998719485035
# Archivo 103tre/rotated_translated103.pdb cadena O creado con éxito.
# 4.9156259316218724 5.652009934862093 1.4297201561676183
# Archivo 103tre/rotated_translated103.pdb cadena P creado con éxito.
# 1.215999057045482 2.3736929024336084 6.2457730426955065
# Archivo 103tre/rotated_translated103.pdb cadena Q creado con éxito.
# 1.9606489158855311 0.9419110175735079 0.3558191649607581
# Archivo 103tre/rotated_translated103.pdb cadena R creado con éxito.
# 1.6776665712976442 1.085508669584308 2.070934567174599
# Archivo 103tre/rotated_translated103.pdb cadena S creado con éxito.
# 5.92053682996797 3.021561816637967 5.267746792718378
# Archivo 103tre/rotated_translated103.pdb cadena T creado con éxito.
# 4.350731718177999 2.557234145675864 3.691167299765476
# Archivo 103tre/rotated_translated103.pdb cadena U creado con éxito.
# 1.906325245062708 3.630684337058971 0.5939159791179052
# Archivo 103tre/rotated_translated103.pdb cadena V creado con éxito.
# 4.435023130562649 3.3821081912546336 4.074331134060067
# Archivo 103tre/rotated_translated103.pdb cadena W creado con éxito.
# 2.318866779297854 4.447908835048782 0.4090628592389075
# Archivo 103tre/rotated_translated103.pdb cadena X creado con éxito.
# 0.2873669202352632 0.37741528406107755 2.5745685554933053
# Archivo 103tre/rotated_translated103.pdb cadena Y creado con éxito.
# 5.300800407016979 1.3259429142978911 2.9762991292279555
# Archivo 103tre/rotated_translated103.pdb cadena Z creado con éxito.
# 4.628209214612146 0.9498183647594125 5.6254259422338055
# Archivo 103tre/rotated_translated103.pdb cadena [ creado con éxito.
# 1.7461949615166275 0.4523220738823347 0.5597952209850496
# Archivo 103tre/rotated_translated103.pdb cadena \ creado con éxito.
# 1.4968704368734909 2.712471640953094 4.556154554040197
# Archivo 103tre/rotated_translated103.pdb cadena ] creado con éxito.
# 0.2802568445056588 5.883646874129377 5.768015572840817
# Archivo 103tre/rotated_translated103.pdb cadena ^ creado con éxito.
# 3.091508675469152 3.731996327175546 0.5786499334709552
# Archivo 103tre/rotated_translated103.pdb cadena _ creado con éxito.
# 2.5662724688816523 4.334486036740964 2.941296781491427
# Archivo 103tre/rotated_translated103.pdb cadena ` creado con éxito.
# 0.43063355672030196 3.7081540212233066 2.108484573137036
# Archivo 103tre/rotated_translated103.pdb cadena a creado con éxito.
# 1.7325863140743873 2.7711656288991664 1.8207560254362243
# Archivo 103tre/rotated_translated103.pdb cadena b creado con éxito.
# 3.982417360315893 3.6282649503300872 2.434346501806288
# Archivo 103tre/rotated_translated103.pdb cadena c creado con éxito.
# 4.912597316887407 2.199788006509145 2.677900005700019
# Archivo 103tre/rotated_translated103.pdb cadena d creado con éxito.
# 4.4396129150293575 2.6251622891229704 3.166440278297451
# Archivo 103tre/rotated_translated103.pdb cadena e creado con éxito.
# 5.673796958109852 2.5111409619924134 4.147141037644333
# Archivo 103tre/rotated_translated103.pdb cadena f creado con éxito.
# 2.593513010193948 4.308253545224285 0.6926650182997321
# Archivo 103tre/rotated_translated103.pdb cadena g creado con éxito.
# 2.1414048325524906 0.6896891845338291 4.88136690268209
# Archivo 103tre/rotated_translated103.pdb cadena h creado con éxito.
# 4.066420376465685 2.6881572969449645 3.688980231131491
# Archivo 103tre/rotated_translated103.pdb cadena i creado con éxito.
# 3.3073028587087085 0.5541143145005631 2.816754983789289
# Archivo 103tre/rotated_translated103.pdb cadena j creado con éxito.
# 1.0560568971794289 3.9895014162339293 5.175694377106524
# Archivo 103tre/rotated_translated103.pdb cadena k creado con éxito.
# 0.5083000066353222 2.3637935256654714 3.248681584856466
# Archivo 103tre/rotated_translated103.pdb cadena l creado con éxito.
# 2.8102724326009305 3.765498998007841 1.094103151056647
# Archivo 103tre/rotated_translated103.pdb cadena m creado con éxito.
# 3.387856040328341 3.591583774022476 6.125968552545246
# Archivo 103tre/rotated_translated103.pdb cadena n creado con éxito.
# 2.62633983081 5.268349525985789 2.883109974392391
# Archivo 103tre/rotated_translated103.pdb cadena o creado con éxito.
# 2.607208676789963 2.01291544676128 3.4434844055244045
# Archivo 103tre/rotated_translated103.pdb cadena p creado con éxito.
# 2.3683511684975005 0.7092858467667389 5.952570745208348
# Archivo 103tre/rotated_translated103.pdb cadena q creado con éxito.
# 0.6691181222229045 2.347872671784843 5.338292500509029
# Archivo 103tre/rotated_translated103.pdb cadena r creado con éxito.
# 2.8875950555362917 1.5737245575987717 2.650577111161397
# Archivo 103tre/rotated_translated103.pdb cadena s creado con éxito.
# 0.16520716447718284 0.9630153390634745 3.6275349671295207
# Archivo 103tre/rotated_translated103.pdb cadena t creado con éxito.
# 3.9972971575796157 4.510320633632272 4.551565708022997
# Archivo 103tre/rotated_translated103.pdb cadena u creado con éxito.
# 2.174675298114061 2.3013877648800576 0.4547056660965557
# Archivo 103tre/rotated_translated103.pdb cadena v creado con éxito.
# 3.8194083687670473 1.976339984764236 2.733626672653075
# Archivo 103tre/rotated_translated103.pdb cadena w creado con éxito.
# 5.861203173889358 1.01461150396605 4.3837671939292
# Archivo 103tre/rotated_translated103.pdb cadena x creado con éxito.
# 2.339409113544813 3.019044321056176 1.4790778113366825
# Archivo 103tre/rotated_translated103.pdb cadena y creado con éxito.
# 0.9032562814152395 0.8809891629531501 1.6647443269565143
# Archivo 103tre/rotated_translated103.pdb cadena z creado con éxito.
# 1.6939584811905177 3.6465408042433656 5.6420252572161536
# Archivo 103tre/rotated_translated103.pdb cadena { creado con éxito.
# 1.2071612510628964 2.639053515530984 1.1931802059544674
# Archivo 103tre/rotated_translated103.pdb cadena | creado con éxito.
# 0.008090724773009999 4.4129449628451045 5.949219302239264
# Archivo 103tre/rotated_translated103.pdb cadena } creado con éxito.
# 1.5463985635178379 1.2913897629954296 3.403413307969419
# Archivo 103tre/rotated_translated103.pdb cadena ~ creado con éxito.
# 3.444906790902126 6.012707180164305 1.823393164562261
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 3.516692767462478 0.3877624055809118 1.3468952813606199
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 0.31694187921628375 2.013403668199825 2.7769350988519648
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 6.183103912032374 0.22845258559579748 4.873513325798853
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 2.497737831289495 3.569496611264335 2.9737798395641697
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 5.596328580652806 1.8114504772286142 0.39637385913532136
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 3.8024180095470657 4.578454146518409 4.499135756984576
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 2.2824736110570663 4.820055287046775 3.570154097725265
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 1.571493096049608 1.0801671901311574 6.173267605641182
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 4.92510244818921 2.5257049910365406 1.8363479864166066
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 4.510764840247388 2.4492414722091747 2.102333048054714
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 3.024407780692256 4.506543129530656 1.704527528748531
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 0.8543174311121923 2.4266011631133138 5.756239739294986
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 0.40609981827627434 0.423882619504825 4.3055448363902515
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 4.233512427208097 3.4147971583371937 1.1057029502607212
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 5.614052172219627 4.068464815122844 3.306476094374153
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 1.7673573686720914 3.489554521129925 2.2770065574930993
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 5.2952609115587475 5.877098863466137 2.8274456654718114
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 4.151699524610717 0.22002433142149228 4.588477104243518
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 0.133775172733907 1.9227633855731734 2.0526403339580606
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 4.437145999620228 6.193490111148546 4.64607096883161
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 0.853415422015958 4.698488011399582 0.4746914746901977
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 5.119866809285884 3.778176719601905 4.39717364123895
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 1.0069927970142885 1.0315723456575439 3.668901553556812
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 3.0372703589413024 2.7234186781054173 5.360631040099601
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 5.245599740355202 1.744191768897566 1.8439994712183552
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 4.550292969890796 5.709930823667812 1.2835220502950127
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 4.0691443447443145 3.1160187800894055 3.164398484825433
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 4.350437694584245 0.43650203380610036 3.263519972549303
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 1.7582208254345661 6.195542985194451 1.6833310505273562
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 5.132175307185285 3.8098060723846117 0.17110068254941152
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 0.8466387449432645 3.6425548588452554 1.357380756488862
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 1.4644446943965912 5.807642988205386 2.8751587318613727
# Archivo 103tre/rotated_translated103.pdb cadena  creado con éxito.
# 1.6180163324978152 3.6003686318101074 5.549168196002869
# Archivo 103tre/rotated_translated103.pdb cadena   creado con éxito.
# 5.321521674771045 0.37576872919829046 2.7035078077722683
# Archivo 103tre/rotated_translated103.pdb cadena ¡ creado con éxito.
# 3.8954098197682483 4.837217884751982 4.419855201354224
# Archivo 103tre/rotated_translated103.pdb cadena ¢ creado con éxito.
# 4.796596556649958 5.6000817656328055 5.5293974941863695
# Archivo 103tre/rotated_translated103.pdb cadena £ creado con éxito.
# 5.156077700312014 1.2257666712508186 0.8011520789960731
# Archivo 103tre/rotated_translated103.pdb cadena ¤ creado con éxito.

# %%
import numpy as np
import os

def read_pdb(file_path):
    coordinates = []
    with open(file_path, 'r') as pdb_file:
        for line in pdb_file:
            if line.startswith('ATOM'):
                x = float(line[30:38])
                y = float(line[38:46])
                z = float(line[46:54])
                coordinates.append([x, y, z])
    return np.array(coordinates)

def write_pdb(file_path, coordinates,chain):
    with open(file_path, 'a') as pdb_file:
        with open('tre-copy.pdb', 'r') as template:
            for line, coord in zip(template, coordinates):
                x_str = f"{coord[0]:8.3f}"
                y_str = f"{coord[1]:8.3f}"
                z_str = f"{coord[2]:8.3f}"
                new_line = f"{line[:25]}{chain}{line[27:31]}{x_str}{y_str}{z_str}{line[54:]}"
                pdb_file.write(new_line)
        pdb_file.write('END\n')
    pdb_file.close

def euler_rotation_matrix(phi, theta, psi):
    R_x = np.array([[1, 0, 0],
                    [0, np.cos(phi), -np.sin(phi)],
                    [0, np.sin(phi), np.cos(phi)]])
    
    R_y = np.array([[np.cos(theta), 0, np.sin(theta)],
                    [0, 1, 0],
                    [-np.sin(theta), 0, np.cos(theta)]])
    
    R_z = np.array([[np.cos(psi), -np.sin(psi), 0],
                    [np.sin(psi), np.cos(psi), 0],
                    [0, 0, 1]])
    
    R = np.dot(R_z, np.dot(R_y, R_x))
    
    return R

def apply_rotation_translation(file_path, phi, theta, psi, translation_vector):
    # Leer el archivo PDB y crear la matriz de coordenadas
    coordinates = read_pdb(file_path)
    print(phi,theta,psi)
    
    # Calcular la matriz de rotación
    R = euler_rotation_matrix(phi, theta, psi)
    
    # Aplicar la rotación a las coordenadas
    rotated_coordinates = np.dot(R, coordinates.T).T
    
    # Aplicar la translación a las coordenadas rotadas
    translated_coordinates = rotated_coordinates + translation_vector
    
    return translated_coordinates

# # Ángulos de Euler originales
# phi = np.pi / 4  # Ángulo de Euler phi (en radianes)
# theta = np.pi / 3  # Ángulo de Euler theta (en radianes)
# psi = np.pi / 6  # Ángulo de Euler psi (en radianes)

# # Vector de translación para cada molécula
# translation_vectors = [
#     np.array([10.0, 10.0, 10.0]),
#     np.array([20.0, 20.0, 20.0]),
#     np.array([30.0, 30.0, 30.0]),
#     np.array([40.0, 40.0, 40.0]),
#     np.array([50.0, 50.0, 50.0]),
#     np.array([60.0, 60.0, 60.0]),
#     np.array([70.0, 70.0, 70.0]),
#     np.array([80.0, 80.0, 80.0]),
#     np.array([90.0, 90.0, 90.0]),
#     np.array([100.0, 100.0, 100.0])
# ]

import os

# Specify the file path
# Crear 10 archivos PDB nuevos con coordenadas rotadas y transladadas
output_directory = "104tre"
file_path = "rotated_translated104.pdb"
output_file_path = os.path.join(output_directory, file_path)

# Check if the file exists before removing it
if os.path.exists(output_file_path):
    # Remove the file
    os.remove(output_file_path)
    print(f"File '{output_file_path}' has been successfully removed.")
else:
    print(f"File '{output_file_path}' does not exist.")

def main():
    output_directory = "104tre"
    os.makedirs(output_directory, exist_ok=True)

if __name__ == "__main__":
    main()
os.makedirs(output_directory, exist_ok=True)

for i in range(100):
    # Introducir variaciones aleatorias en los ángulos de Euler
    phi_random = np.random.uniform(0, 2*np.pi)  # Variación de +/- 15 grados
    theta_random = np.random.uniform(0,2*np.pi)
    psi_random = np.random.uniform(0,2*np.pi)
    translation_vector=[np.random.uniform(-20,20),np.random.uniform(-20,20),np.random.uniform(-20,20)]
    
    rotated_translated_coordinates = apply_rotation_translation('tre-copy.pdb', phi_random, theta_random, psi_random, translation_vector)
    chain=chr(ord('A') + i )
    write_pdb(output_file_path, rotated_translated_coordinates,chain)
    print(f"Archivo {output_file_path} cadena {chain} creado con éxito.")
# Out:
# File '104tre/rotated_translated104.pdb' does not exist.
# 0.01764634259009492 3.3490906543115826 5.853822746710283
# Archivo 104tre/rotated_translated104.pdb cadena A creado con éxito.
# 4.634511803257509 2.4448225068464 3.2979515741984207
# Archivo 104tre/rotated_translated104.pdb cadena B creado con éxito.
# 0.9118249018916945 3.2313620755080543 2.6102208725571105
# Archivo 104tre/rotated_translated104.pdb cadena C creado con éxito.
# 4.5164851784661595 2.728120475225361 4.420347149209592
# Archivo 104tre/rotated_translated104.pdb cadena D creado con éxito.
# 4.871198076958559 3.030270126131091 3.2760129014613724
# Archivo 104tre/rotated_translated104.pdb cadena E creado con éxito.
# 3.4528762771828325 5.27594880546833 5.047768480584972
# Archivo 104tre/rotated_translated104.pdb cadena F creado con éxito.
# 5.19762015215432 6.045357630078411 3.35003800872094
# Archivo 104tre/rotated_translated104.pdb cadena G creado con éxito.
# 0.7467469095547519 0.9930807823698632 5.952658602921149
# Archivo 104tre/rotated_translated104.pdb cadena H creado con éxito.
# 5.332705416532221 4.472415284652986 2.1444868123697614
# Archivo 104tre/rotated_translated104.pdb cadena I creado con éxito.
# 1.5127108047899778 4.297778906265058 3.0423929522342976
# Archivo 104tre/rotated_translated104.pdb cadena J creado con éxito.
# 5.741907177992131 2.4108208435327576 4.967413185748206
# Archivo 104tre/rotated_translated104.pdb cadena K creado con éxito.
# 0.9264475825713621 2.1408579668159637 1.8089819096888797
# Archivo 104tre/rotated_translated104.pdb cadena L creado con éxito.
# 3.323214844155973 1.8839460805476953 0.9311481526344304
# Archivo 104tre/rotated_translated104.pdb cadena M creado con éxito.
# 1.6183452365329787 3.700848498908539 2.4493422399327023
# Archivo 104tre/rotated_translated104.pdb cadena N creado con éxito.
# 1.4316946654076532 1.5698914566372588 0.6155151715160779
# Archivo 104tre/rotated_translated104.pdb cadena O creado con éxito.
# 4.270340036846377 5.039963733661148 2.405863203126362
# Archivo 104tre/rotated_translated104.pdb cadena P creado con éxito.
# 6.135856277339077 2.267088846002097 0.14691127915002336
# Archivo 104tre/rotated_translated104.pdb cadena Q creado con éxito.
# 1.9742646885011865 6.178065235663353 3.940961359138698
# Archivo 104tre/rotated_translated104.pdb cadena R creado con éxito.
# 3.8256759094233916 0.8671679512049223 1.1943365405172892
# Archivo 104tre/rotated_translated104.pdb cadena S creado con éxito.
# 1.8017181988005873 3.564861666940078 3.358038343589785
# Archivo 104tre/rotated_translated104.pdb cadena T creado con éxito.
# 4.700838056296535 2.589008518563722 4.7045921630215295
# Archivo 104tre/rotated_translated104.pdb cadena U creado con éxito.
# 1.3509232796118353 0.1648068309999037 1.6010682787221129
# Archivo 104tre/rotated_translated104.pdb cadena V creado con éxito.
# 2.354899423128863 0.9999583929988317 2.8025921424000257
# Archivo 104tre/rotated_translated104.pdb cadena W creado con éxito.
# 2.3779017224686263 4.048770447385817 2.0683394353488187
# Archivo 104tre/rotated_translated104.pdb cadena X creado con éxito.
# 3.689922995875085 1.8654269452069283 6.042352006014475
# Archivo 104tre/rotated_translated104.pdb cadena Y creado con éxito.
# 1.5043876939595546 2.6906445382424633 0.0355194839986556
# Archivo 104tre/rotated_translated104.pdb cadena Z creado con éxito.
# 1.3491993593794986 1.381922427582111 0.24717645432711374
# Archivo 104tre/rotated_translated104.pdb cadena [ creado con éxito.
# 1.9839720017159208 3.9578615260657326 1.5427649286702407
# Archivo 104tre/rotated_translated104.pdb cadena \ creado con éxito.
# 6.004115343103068 0.18412178869406057 0.7576315953020277
# Archivo 104tre/rotated_translated104.pdb cadena ] creado con éxito.
# 2.936968784236153 5.298539087425232 2.255476089732951
# Archivo 104tre/rotated_translated104.pdb cadena ^ creado con éxito.
# 6.216396170201315 2.8178918067807937 2.9632350080061056
# Archivo 104tre/rotated_translated104.pdb cadena _ creado con éxito.
# 2.2718898515010215 1.7434983031348303 1.197035393563987
# Archivo 104tre/rotated_translated104.pdb cadena ` creado con éxito.
# 1.9401594263315498 1.2847483672114286 4.441877154790272
# Archivo 104tre/rotated_translated104.pdb cadena a creado con éxito.
# 4.458714831288544 3.200559097154437 3.4827918179590367
# Archivo 104tre/rotated_translated104.pdb cadena b creado con éxito.
# 5.798838062690863 4.163538878435451 2.6319550144776063
# Archivo 104tre/rotated_translated104.pdb cadena c creado con éxito.
# 2.387566913263987 5.800670660834311 3.0362551839031413
# Archivo 104tre/rotated_translated104.pdb cadena d creado con éxito.
# 1.1939731812965222 5.215719885955646 0.971679490772913
# Archivo 104tre/rotated_translated104.pdb cadena e creado con éxito.
# 2.7801905154716597 2.1301010834372254 4.626564568304761
# Archivo 104tre/rotated_translated104.pdb cadena f creado con éxito.
# 0.25767716625629167 0.9787462019330143 3.261818316123618
# Archivo 104tre/rotated_translated104.pdb cadena g creado con éxito.
# 0.764700541943855 5.191262085592724 1.4920183920466956
# Archivo 104tre/rotated_translated104.pdb cadena h creado con éxito.
# 1.0808770506262504 2.1169034951596677 4.633120788686881
# Archivo 104tre/rotated_translated104.pdb cadena i creado con éxito.
# 3.8921840741999514 4.839577702506711 3.2509760281342266
# Archivo 104tre/rotated_translated104.pdb cadena j creado con éxito.
# 0.8865170673050793 4.690960258671506 4.276020759019468
# Archivo 104tre/rotated_translated104.pdb cadena k creado con éxito.
# 1.1176461189689608 3.937784679469318 2.683221409179374
# Archivo 104tre/rotated_translated104.pdb cadena l creado con éxito.
# 3.7627129448391865 1.4382295129907596 4.1086390464714455
# Archivo 104tre/rotated_translated104.pdb cadena m creado con éxito.
# 0.06553996796159917 4.919027939839964 6.157074223744167
# Archivo 104tre/rotated_translated104.pdb cadena n creado con éxito.
# 3.061639283680932 0.07557661928843891 0.9027217446717312
# Archivo 104tre/rotated_translated104.pdb cadena o creado con éxito.
# 5.814376262890265 4.214924570862718 6.0176706552893116
# Archivo 104tre/rotated_translated104.pdb cadena p creado con éxito.
# 0.8371396340830916 5.46907341486347 4.1870318484587035
# Archivo 104tre/rotated_translated104.pdb cadena q creado con éxito.
# 2.193698142697002 3.637420708390719 0.8722876582042801
# Archivo 104tre/rotated_translated104.pdb cadena r creado con éxito.
# 3.690164775045388 5.222167210077716 5.810546806884594
# Archivo 104tre/rotated_translated104.pdb cadena s creado con éxito.
# 4.210950564457295 4.491743507796673 1.1590626839555924
# Archivo 104tre/rotated_translated104.pdb cadena t creado con éxito.
# 3.326883763389762 1.5283466586139067 4.009733249684125
# Archivo 104tre/rotated_translated104.pdb cadena u creado con éxito.
# 0.9510716429854211 4.288264446645605 2.6311763320370387
# Archivo 104tre/rotated_translated104.pdb cadena v creado con éxito.
# 0.32067258225507767 6.246019388529791 5.547179074044798
# Archivo 104tre/rotated_translated104.pdb cadena w creado con éxito.
# 4.255716751287603 3.2239496099508074 1.9440486429290722
# Archivo 104tre/rotated_translated104.pdb cadena x creado con éxito.
# 4.944866145309028 5.907731862792932 6.19627187058291
# Archivo 104tre/rotated_translated104.pdb cadena y creado con éxito.
# 1.8228394805590378 0.45420486794849857 4.037689163297833
# Archivo 104tre/rotated_translated104.pdb cadena z creado con éxito.
# 1.8916757664951322 3.3770908383693916 2.704411111697773
# Archivo 104tre/rotated_translated104.pdb cadena { creado con éxito.
# 2.842038433733937 2.7354145893171538 2.997985825368467
# Archivo 104tre/rotated_translated104.pdb cadena | creado con éxito.
# 0.36660593621520615 2.63433512798626 1.2623979439447057
# Archivo 104tre/rotated_translated104.pdb cadena } creado con éxito.
# 4.446957310498006 1.5614903700942542 5.692504843449998
# Archivo 104tre/rotated_translated104.pdb cadena ~ creado con éxito.
# 4.241007021300868 3.4379504541421215 4.151292307878588
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 2.6841484412724723 0.6532783607117445 1.941726599456662
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 0.20453051477074988 1.591415963917638 0.2831926218099698
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 6.021266164944049 0.041271609556580775 0.5749752447133678
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 2.200146604334324 5.410483634546523 4.751907393904861
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 4.0713031994118465 1.1368804903396112 2.805060596593397
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 3.0880256983736105 6.132907566224591 4.523333900415194
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 5.749076310138682 1.5693323550734046 1.1410215842368543
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 3.4589927100723084 0.7384380102481533 4.893061756235977
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 4.105058352929934 5.276247707842478 4.840821682458126
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 0.14472014200045186 3.841099295878297 3.295604426334315
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 1.5672360279827973 4.1183527988879725 4.571262724816035
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 1.0351173765904276 1.1503925749052932 5.033810657405229
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 0.6455961035203989 5.099978376592231 3.368978529398164
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 3.2119775544904074 5.618726367793286 3.0342396912121887
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 5.851417461182078 5.351876678207283 4.7519971435329085
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 2.5364888413629503 0.265966405596268 3.8136337228480772
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 2.6130450921981607 1.6114720071747854 6.0444603812222475
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 2.3076292068255277 3.8136889774932667 2.0952702434536925
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 3.8655481693197964 5.229172847429342 2.2096207417485854
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 4.869928159929163 2.5341662898204453 3.4049864731285813
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 1.839649593105618 4.318020042409064 4.155763866365405
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 5.720106271700097 1.6562311107181136 3.5363354563421083
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 3.6451024565090497 6.2756064133946365 1.6414856318598843
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 4.005639338931828 3.606847257478278 1.2402738658701935
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 0.5473212638922706 0.7511020157185772 1.2955046727911712
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 2.3097376802382805 1.504669321127021 1.5713925121496743
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 1.232654384238171 5.754130412980986 3.553819700745834
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 4.5670040742890405 3.838314943180028 4.9528920847143185
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 1.9559625528600744 0.4663312068457564 5.458129851662938
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 2.7544400689666664 1.3248023831038072 6.000124141421536
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 1.9565673296263886 1.6761627411351894 2.1583414803774446
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 0.6550065210098214 1.608613164540193 3.3831556784976082
# Archivo 104tre/rotated_translated104.pdb cadena  creado con éxito.
# 3.312900120132237 0.12695536622073644 5.027279269872247
# Archivo 104tre/rotated_translated104.pdb cadena   creado con éxito.
# 0.5373084113933526 0.3207184841700071 4.663324997987387
# Archivo 104tre/rotated_translated104.pdb cadena ¡ creado con éxito.
# 0.4176406662225333 0.7697097463156731 3.96427790038655
# Archivo 104tre/rotated_translated104.pdb cadena ¢ creado con éxito.
# 0.7714181476375125 5.128986664174907 1.2400940136568315
# Archivo 104tre/rotated_translated104.pdb cadena £ creado con éxito.
# 3.58417841364647 5.64491445660777 3.2917246867411327
# Archivo 104tre/rotated_translated104.pdb cadena ¤ creado con éxito.

# %% [markdown]
# intentem fer-ho comptant que l'abecedari té només 26 lletres, hem de fer-ho d'una altra manera

# %%
import numpy as np
import os

def read_pdb(file_path):
    coordinates = []
    with open(file_path, 'r') as pdb_file:
        for line in pdb_file:
            if line.startswith('ATOM'):
                x = float(line[30:38])
                y = float(line[38:46])
                z = float(line[46:54])
                coordinates.append([x, y, z])
    return np.array(coordinates)

def write_pdb(file_path, coordinates, chain):
    with open(file_path, 'a') as pdb_file:
        for coord in coordinates:
            x_str = f"{coord[0]:8.3f}"
            y_str = f"{coord[1]:8.3f}"
            z_str = f"{coord[2]:8.3f}"
            new_line = f"ATOM  {len(chain):>5} {chain:>1}{' ' * 4}{x_str}{y_str}{z_str}{' ' * 26}\n"
            pdb_file.write(new_line)
        pdb_file.write('END\n')

def euler_rotation_matrix(phi, theta, psi):
    R_x = np.array([[1, 0, 0],
                    [0, np.cos(phi), -np.sin(phi)],
                    [0, np.sin(phi), np.cos(phi)]])
    
    R_y = np.array([[np.cos(theta), 0, np.sin(theta)],
                    [0, 1, 0],
                    [-np.sin(theta), 0, np.cos(theta)]])
    
    R_z = np.array([[np.cos(psi), -np.sin(psi), 0],
                    [np.sin(psi), np.cos(psi), 0],
                    [0, 0, 1]])
    
    R = np.dot(R_z, np.dot(R_y, R_x))
    
    return R

def apply_rotation_translation(file_path, phi, theta, psi, translation_vector):
    coordinates = read_pdb(file_path)
    
    R = euler_rotation_matrix(phi, theta, psi)
    
    rotated_coordinates = np.dot(R, coordinates.T).T
    
    translated_coordinates = rotated_coordinates + translation_vector
    
    return translated_coordinates

def main():
    output_directory = "100tre"
    os.makedirs(output_directory, exist_ok=True)
    output_file_path = os.path.join(output_directory, "rotated_translated.pdb")

    if os.path.exists(output_file_path):
        os.remove(output_file_path)
        print(f"File '{output_file_path}' has been successfully removed.")
    else:
        print(f"File '{output_file_path}' does not exist.")

    for i in range(100):
        phi_random = np.random.uniform(0, 2*np.pi)
        theta_random = np.random.uniform(0, 2*np.pi)
        psi_random = np.random.uniform(0, 2*np.pi)
        translation_vector = [np.random.uniform(-20, 20) for _ in range(3)]
        
        rotated_translated_coordinates = apply_rotation_translation('tre-copy.pdb', phi_random, theta_random, psi_random, translation_vector)
        
        chain = chr(ord('A') + i)
        
        write_pdb(output_file_path, rotated_translated_coordinates, chain)
        print(f"Archivo {output_file_path} cadena {chain} creado con éxito.")

if __name__ == "__main__":
    main()
# Out:
# File '100tre/rotated_translated.pdb' has been successfully removed.
# Archivo 100tre/rotated_translated.pdb cadena A creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena B creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena C creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena D creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena E creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena F creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena G creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena H creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena I creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena J creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena K creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena L creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena M creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena N creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena O creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena P creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena Q creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena R creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena S creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena T creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena U creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena V creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena W creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena X creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena Y creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena Z creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena [ creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena \ creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena ] creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena ^ creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena _ creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena ` creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena a creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena b creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena c creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena d creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena e creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena f creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena g creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena h creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena i creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena j creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena k creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena l creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena m creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena n creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena o creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena p creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena q creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena r creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena s creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena t creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena u creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena v creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena w creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena x creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena y creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena z creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena { creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena | creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena } creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena ~ creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena  creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena   creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena ¡ creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena ¢ creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena £ creado con éxito.
# Archivo 100tre/rotated_translated.pdb cadena ¤ creado con éxito.
